# %% [markdown]
# #### Imports

# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Load data
df = pd.read_csv('./datasets/CovidVaccinations.csv', sep=';', decimal=',', parse_dates=['date'], dayfirst=True)

# Change date format to YYYY-MM-DD
df['date'] = df['date'].dt.strftime('%Y-%m-%d')

# Replace commas with periods in all columns
for col in df.columns:
    if df[col].dtype == object:
        df[col] = df[col].str.replace(',', '.')

# Handle missing values
df.fillna('NULL', inplace=True)

# %%
df.head()
# Out:
#   iso_code continent     location        date new_tests total_tests  \
# 0      AFG      Asia  Afghanistan  2020-02-24      NULL        NULL
# 1      AFG      Asia  Afghanistan  2020-02-25      NULL        NULL
# 2      AFG      Asia  Afghanistan  2020-02-26      NULL        NULL
# 3      AFG      Asia  Afghanistan  2020-02-27      NULL        NULL
# 4      AFG      Asia  Afghanistan  2020-02-28      NULL        NULL
#
#   total_tests_per_thousand new_tests_per_thousand new_tests_smoothed  \
# 0                     NULL                   NULL               NULL
# 1                     NULL                   NULL               NULL
# 2                     NULL                   NULL               NULL
# 3                     NULL                   NULL               NULL
# 4                     NULL                   NULL               NULL
#
#   new_tests_smoothed_per_thousand  ... gdp_per_capita extreme_poverty  \
# ...

# %%
# Save the DataFrame to a new CSV file
df.to_csv('covidvaccinations1.csv', index=False)

# %%
# Load data
df = pd.read_csv('./datasets/covidvaccinations1.csv')

# Create SQL engine
engine = create_engine('mysql+mysqlconnector://root:password@localhost:3306/Portfolio')

# Write data to SQL
df.to_sql('covidvaccinations', engine, if_exists='append', index=False)
# Out:
# -1
